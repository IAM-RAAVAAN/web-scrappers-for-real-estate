# %%
import csv 
import os 
import sys

# %%
    os.chdir(r'C:\Users\swaraj\Desktop\codes\modules\working')
    # print(i)
    
    #print (os.getcwd())
    directory = os.listdir()

# %%
import pandas as pd 
import numpy as np
d={}
fr=[]
csv_files = []
for files in directory:
        #print(files)
        if files.endswith(".csv"):
            csv_files.append(files)
            #print(files, "-----------------------")
            f = pd.read_csv(files)

            # print(time.time()-e1234)
            #f['file_name'] = files
            # print(f)
            d[files]=f
            fr.append(f)
            files = files[:files.index('.')]
            ([files])

# %%
d['commonfloor.csv'].columns=['0','area','bathrooms','text','link','title','prices','dates','owner','furnished']
d['prop.csv'].columns=['0','title','link','text','area','prices']
d['propertywala.csv'].columns=['0','title','owner','area','text','link']
d['housing.csv'].columns=['0','prices','location','furnished','owner','link','title','area']
d['sulekha.csv'].columns=['0','title','link','location','text','text1','co-ordinate','area','prices','depo','dates','owner']
d['scraped_data.csv'].columns=['0','type','prices','area','link','title','depo','furnished','location','owner']
d['magicbricks.csv'].columns=['0','text','owner','title','prices','location']

# %%
# d['99acers.csv']
# Out:
#     Unnamed: 0                                               link  \
# 0            0  /2-bhk-bedroom-residential-apartments-for-rent...
# 1            1  /2-bhk-bedroom-residential-apartments-for-rent...
# 2            2  /3-bhk-bedroom-residential-apartments-for-rent...
# 3            3  /4-bhk-bedroom-independent-house-for-rent-in-m...
# 4            4  /1-bhk-bedroom-residential-apartments-for-rent...
# 5            5  /2-bhk-bedroom-residential-apartments-for-rent...
# 6            6  /3-bhk-bedroom-residential-apartments-for-rent...
# 7            7  /2-bhk-bedroom-residential-apartments-for-rent...
# 8            8  /3-bhk-bedroom-residential-apartments-for-rent...
# 9            9  /2-bhk-bedroom-residential-apartments-for-rent...
# 10          10  /3-bhk-bedroom-residential-apartments-for-rent...
# 11          11  /2-bhk-bedroom-residential-apartments-for-rent...
# 12          12  /2-bhk-bedroom-residential-apartments-for-rent...
# ...

# %%
f=[]
for k in d.keys():
    # print(k)
    # print(d[k].columns)
    f.append(d[k])
# Out:
# 99acers.csv
# Index(['Unnamed: 0', 'link', 'title', 'prices', 'location', 'type', 'area',
#        'text'],
#       dtype='object')
# 99acers2.csv
# Index(['Unnamed: 0', 'link', 'title', 'prices', 'location', 'type', 'area',
#        'text', 'dates'],
#       dtype='object')
# 99acers2_pa.csv
# Index(['Unnamed: 0', 'link', 'title', 'prices', 'location', 'place', 'type',
#        'area', 'dates', 'names'],
#       dtype='object')
# commonfloor.csv
# Index(['0', 'area', 'bathrooms', 'text', 'link', 'title', 'prices', 'dates',
#        'owner', 'furnished'],
#       dtype='object')
# hjjolkkjj99acers2.csv
# Index(['Unnamed: 0', 'link', 'title', 'prices', 'location', 'type', 'area',
#        'dates'],
#       dtype='object')
# housing.csv
# Index(['0', 'prices', 'location', 'furnished', 'owner', 'link', 'title',
#        'area'],
#       dtype='object')
# magicbricks.csv
# Index(['0', 'text', 'owner', 'title', 'prices', 'location'], dtype='object')
# prop.csv
# ...

# %%
re=pd.concat(f[1:])

# %%
re
# Out:
#      Unnamed: 0                                               link  \
# 0           0.0  https://www.99acres.com/1-bhk-bedroom-farm-hou...
# 1           1.0  https://www.99acres.com/3-bhk-bedroom-independ...
# 2           2.0  https://www.99acres.com/residential-land-for-s...
# 3           3.0  https://www.99acres.com/residential-land-for-s...
# 4           4.0  https://www.99acres.com/2-bhk-bedroom-resident...
# ..          ...                                                ...
# 120         NaN  https://property.sulekha.com/apartments-flats-...
# 121         NaN  https://property.sulekha.com/apartments-flats-...
# 122         NaN  https://property.sulekha.com/apartments-flats-...
# 123         NaN  https://property.sulekha.com/apartments-flats-...
# 124         NaN  https://property.sulekha.com/apartments-flats-...
#
#                                                  title  \
# 0                         1 Bedroom Farm house in Mhow
# ...

# %%
re=re.drop(['Unnamed: 0','0','names'],axis=1)

# %%
re=re.drop(['place'],axis=1)

# %%
re.to_csv('data_still.csv')
